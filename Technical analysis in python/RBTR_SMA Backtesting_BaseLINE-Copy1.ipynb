# %% [markdown]
# # Generalization with OOP: The SMABacktester Class

# %% [markdown]
# ## Using the SMABacktester Class

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import brute
import pyfolio as pf
import warnings

warnings.simplefilter("ignore")

# %%
import SMABacktester as SMA

# %%
tester = SMA.SMABacktester("^GSPC", 50, 200, "2004-01-01", "2020-06-30")

# %%
tester
# Out:
# SMABacktester(symbol = ^GSPC, SMA_S = 50, SMA_L = 200, start = 2004-01-01, end = 2020-06-30)

# %%
tester.test_strategy()
# Out:
# (1.928765, -0.85421)

# %%
tester.results
# Out:
#                                  price   returns        SMA_S        SMA_L  \
# Date
# 2004-10-19 00:00:00-04:00  1103.229980 -0.009733  1109.942607  1119.950300
# 2004-10-20 00:00:00-04:00  1103.660034  0.000390  1110.435007  1119.857501
# 2004-10-21 00:00:00-04:00  1106.489990  0.002561  1111.049006  1119.771600
# 2004-10-22 00:00:00-04:00  1095.739990 -0.009763  1111.699207  1119.618651
# 2004-10-25 00:00:00-04:00  1094.800049 -0.000858  1112.299207  1119.433051
# ...                                ...       ...          ...          ...
# 2020-06-24 00:00:00-04:00  3050.330078 -0.026195  2969.864404  3020.380143
# 2020-06-25 00:00:00-04:00  3083.760010  0.010900  2975.872402  3020.901993
# 2020-06-26 00:00:00-04:00  3009.050049 -0.024525  2980.062402  3020.942594
# 2020-06-29 00:00:00-04:00  3053.239990  0.014579  2983.636001  3021.160944
# 2020-06-30 00:00:00-04:00  3100.290039  0.015292  2989.178604  3021.625444
#
# ...

# %%
tester.plot_results()

# %%
tester.set_parameters(22, 100)

# %%
tester.test_strategy()
# Out:
# (1.097396, -1.688005)

# %%
tester.plot_results()

# %%
tester.optimize_parameters((25, 50, 1), (100, 200, 1))
# Out:
# (array([ 48., 163.]), 2.406449)

# %%
tester.plot_results()

# %%
tester.results
# Out:
#                                  price   returns        SMA_S        SMA_L  \
# Date
# 2004-08-26 00:00:00-04:00  1105.089966  0.000118  1103.383952  1120.389630
# 2004-08-27 00:00:00-04:00  1107.770020  0.002422  1102.914576  1120.300980
# 2004-08-30 00:00:00-04:00  1099.150024 -0.007812  1102.179993  1120.150550
# 2004-08-31 00:00:00-04:00  1104.239990  0.004620  1101.350408  1120.015029
# 2004-09-01 00:00:00-04:00  1105.910034  0.001511  1100.626658  1119.855458
# ...                                ...       ...          ...          ...
# 2020-06-24 00:00:00-04:00  3050.330078 -0.026195  2977.298126  3029.209380
# 2020-06-25 00:00:00-04:00  3083.760010  0.010900  2981.656459  3029.492815
# 2020-06-26 00:00:00-04:00  3009.050049 -0.024525  2985.529170  3029.137847
# 2020-06-29 00:00:00-04:00  3053.239990  0.014579  2992.126668  3028.984288
# 2020-06-30 00:00:00-04:00  3100.290039  0.015292  2998.397085  3029.141772
#
# ...

# %%
pf.create_returns_tear_sheet(tester.results.returns, live_start_date='2018-1-1')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=4>2004-08-26</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=4>2020-06-30</td></tr>
#     <tr style="text-align: right;"><th>In-sample months</th><td colspan=4>160</td></tr>
#     <tr style="text-align: right;"><th>Out-of-sample months</th><td colspan=4>29</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>In-sample</th>
#       <th>Out-of-sample</th>
#       <th>All</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>4.988%</td>
#       <td>2.916%</td>
#       <td>4.659%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>91.411%</td>
#       <td>7.425%</td>
#       <td>105.622%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>18.714%</td>
#       <td>24.638%</td>
#       <td>19.761%</td>
#     </tr>
#     <tr>
# ...

# %%
pf.create_returns_tear_sheet(tester.results.strategy, live_start_date='2018-1-1')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=4>2004-08-26</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=4>2020-06-30</td></tr>
#     <tr style="text-align: right;"><th>In-sample months</th><td colspan=4>160</td></tr>
#     <tr style="text-align: right;"><th>Out-of-sample months</th><td colspan=4>29</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>In-sample</th>
#       <th>Out-of-sample</th>
#       <th>All</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>7.004%</td>
#       <td>-12.573%</td>
#       <td>3.654%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>146.683%</td>
#       <td>-28.455%</td>
#       <td>76.49%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>18.711%</td>
#       <td>24.632%</td>
#       <td>19.762%</td>
#     </tr>
#     <tr>
# ...

# %%
ccl = yf.Ticker("^GSPC")
df = ccl.history(period="max")
df = df[['Close']]

pf.create_returns_tear_sheet(tester.results.strategy, live_start_date='2017-1-1')
