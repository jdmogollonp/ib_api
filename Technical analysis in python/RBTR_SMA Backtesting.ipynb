# %% [markdown]
# # Generalization with OOP: The SMABacktester Class

# %% [markdown]
# ## Using the SMABacktester Class

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import brute
import pyfolio as pf
import warnings

warnings.simplefilter("ignore")

# %%
import SMABacktester as SMA

# %%
tester = SMA.SMABacktester("EQT", 50, 200, "2004-01-01", "2020-06-30")
# Out:
# D:\Users\Usuario\Desktop\UPM Trading\ib_api\Technical analysis in python\SMABacktester.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw.rename(columns={"Close": "price"}, inplace=True)
# D:\Users\Usuario\Desktop\UPM Trading\ib_api\Technical analysis in python\SMABacktester.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw["returns"] = np.log(raw.price / raw.price.shift(1))
# D:\Users\Usuario\Desktop\UPM Trading\ib_api\Technical analysis in python\SMABacktester.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw["SMA_S"] = raw["price"].rolling(self.SMA_S).mean()
# D:\Users\Usuario\Desktop\UPM Trading\ib_api\Technical analysis in python\SMABacktester.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw["SMA_L"] = raw["price"].rolling(self.SMA_L).mean()

# %%
tester
# Out:
# SMABacktester(symbol = EQT, SMA_S = 50, SMA_L = 200, start = 2004-01-01, end = 2020-06-30)

# %%
tester.test_strategy()
# Out:
# (7.064793, 6.090139)

# %%
tester.results
# Out:
#                                price   returns      SMA_S      SMA_L  \
# Date
# 2004-10-19 00:00:00-04:00  11.878036 -0.006631  11.601798  10.464045
# 2004-10-20 00:00:00-04:00  12.053651  0.014677  11.620764  10.477895
# 2004-10-21 00:00:00-04:00  12.084382  0.002546  11.641003  10.492403
# 2004-10-22 00:00:00-04:00  11.976817 -0.008941  11.659882  10.506427
# 2004-10-25 00:00:00-04:00  12.051454  0.006212  11.678497  10.520652
# ...                              ...       ...        ...        ...
# 2020-06-24 00:00:00-04:00  11.742130 -0.021453  13.497281   9.845185
# 2020-06-25 00:00:00-04:00  11.144742 -0.052215  13.464571   9.843568
# 2020-06-26 00:00:00-04:00  10.429832 -0.066298  13.422264   9.835852
# 2020-06-29 00:00:00-04:00  10.831357  0.037775  13.377019   9.830338
# 2020-06-30 00:00:00-04:00  11.653992  0.073203  13.305333   9.829568
#
#                            position  strategy  creturns  cstrategy
# Date
# 2004-10-19 00:00:00-04:00         1 -0.006631  0.993391   0.993391
# 2004-10-20 00:00:00-04:00         1  0.014677  1.008078   1.008078
# 2004-10-21 00:00:00-04:00         1  0.002546  1.010648   1.010648
# 2004-10-22 00:00:00-04:00         1 -0.008941  1.001652   1.001652
# 2004-10-25 00:00:00-04:00         1  0.006212  1.007894   1.007894
# ...                             ...       ...       ...        ...
# 2020-06-24 00:00:00-04:00         1 -0.021453  0.982024   7.118223
# 2020-06-25 00:00:00-04:00         1 -0.052215  0.932063   6.756079
# 2020-06-26 00:00:00-04:00         1 -0.066298  0.872274   6.322692
# 2020-06-29 00:00:00-04:00         1  0.037775  0.905854   6.566101
# 2020-06-30 00:00:00-04:00         1  0.073203  0.974653   7.064793
#
# [3952 rows x 8 columns]

# %%
tester.plot_results()

# %%
tester.set_parameters(22, 100)

# %%
tester.test_strategy()
# Out:
# (24.503615, 23.396658)

# %%
tester.plot_results()

# %%
tester.optimize_parameters((25, 50, 1), (100, 200, 1))
# Out:
# (array([ 25., 104.]), 44.018344)

# %%
tester.plot_results()

# %%
tester.results
# Out:
#                                price   returns      SMA_S      SMA_L  \
# Date
# 2004-06-02 00:00:00-04:00  10.565001 -0.004732  10.273590   9.679783
# 2004-06-03 00:00:00-04:00  10.460413 -0.009949  10.281813   9.691098
# 2004-06-04 00:00:00-04:00  10.419018 -0.003965  10.288813   9.702984
# 2004-06-07 00:00:00-04:00  10.512706  0.008952  10.303104   9.715875
# 2004-06-08 00:00:00-04:00  10.360191 -0.014614  10.311123   9.726969
# ...                              ...       ...        ...        ...
# 2020-06-24 00:00:00-04:00  11.742130 -0.021453  13.662787  10.074248
# 2020-06-25 00:00:00-04:00  11.144742 -0.052215  13.586400  10.118864
# 2020-06-26 00:00:00-04:00  10.429832 -0.066298  13.487683  10.162129
# 2020-06-29 00:00:00-04:00  10.831357  0.037775  13.382700  10.208319
# 2020-06-30 00:00:00-04:00  11.653992  0.073203  13.271056  10.263730
#
#                            position  strategy  creturns  cstrategy
# Date
# 2004-06-02 00:00:00-04:00         1 -0.004732  0.995280   0.995280
# 2004-06-03 00:00:00-04:00         1 -0.009949  0.985427   0.985427
# 2004-06-04 00:00:00-04:00         1 -0.003965  0.981527   0.981527
# 2004-06-07 00:00:00-04:00         1  0.008952  0.990353   0.990353
# 2004-06-08 00:00:00-04:00         1 -0.014614  0.975985   0.975985
# ...                             ...       ...       ...        ...
# 2020-06-24 00:00:00-04:00         1 -0.021453  1.106171  44.351252
# 2020-06-25 00:00:00-04:00         1 -0.052215  1.049894  42.094854
# 2020-06-26 00:00:00-04:00         1 -0.066298  0.982546  39.394563
# 2020-06-29 00:00:00-04:00         1  0.037775  1.020372  40.911166
# 2020-06-30 00:00:00-04:00         1  0.073203  1.097868  44.018344
#
# [4048 rows x 8 columns]

# %%
pf.create_returns_tear_sheet(tester.results.strategy, live_start_date='2017-1-1')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=4>2004-06-02</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=4>2020-06-30</td></tr>
#     <tr style="text-align: right;"><th>In-sample months</th><td colspan=4>150</td></tr>
#     <tr style="text-align: right;"><th>Out-of-sample months</th><td colspan=4>41</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>In-sample</th>
#       <th>Out-of-sample</th>
#       <th>All</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>19.007%</td>
#       <td>9.77%</td>
#       <td>16.937%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>791.986%</td>
#       <td>38.422%</td>
#       <td>1134.707%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>33.858%</td>
#       <td>55.368%</td>
#       <td>39.528%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.68</td>
#       <td>0.45</td>
#       <td>0.60</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.32</td>
#       <td>0.15</td>
#       <td>0.26</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.96</td>
#       <td>0.62</td>
#       <td>0.96</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-59.697%</td>
#       <td>-64.301%</td>
#       <td>-64.301%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.14</td>
#       <td>1.09</td>
#       <td>1.12</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.99</td>
#       <td>0.63</td>
#       <td>0.85</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.16</td>
#       <td>-0.65</td>
#       <td>-0.47</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>9.08</td>
#       <td>11.09</td>
#       <td>13.85</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.01</td>
#       <td>1.04</td>
#       <td>1.05</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-4.174%</td>
#       <td>-6.876%</td>
#       <td>-4.887%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>64.30</td>
#       <td>2020-02-26</td>
#       <td>2020-06-26</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>59.70</td>
#       <td>2008-10-10</td>
#       <td>2009-03-03</td>
#       <td>2011-05-31</td>
#       <td>688</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>33.55</td>
#       <td>2014-10-13</td>
#       <td>2015-07-02</td>
#       <td>2015-12-09</td>
#       <td>303</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>31.71</td>
#       <td>2018-11-16</td>
#       <td>2019-06-05</td>
#       <td>2019-08-14</td>
#       <td>194</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>28.80</td>
#       <td>2011-10-24</td>
#       <td>2012-07-12</td>
#       <td>2013-05-09</td>
#       <td>404</td>
#     </tr>
#   </tbody>
# </table>

# %%
pf.create_returns_tear_sheet(tester.results.strategy, live_start_date='2017-1-1')
