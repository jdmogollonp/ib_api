# %%
import yfinance as yf

# Set the ticker symbol and the time period
ticker = "AAPL"
start_date = "2022-01-01"
end_date = "2023-03-06"

# Set the interval to 1 hour
interval = "1h"

# Retrieve the stock data
data = yf.download(ticker, start=start_date, end=end_date, interval=interval)

# Print the data
print(data)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2022-01-03 09:30:00-05:00  177.830002  181.429993  177.710007  180.839996
# 2022-01-03 10:30:00-05:00  180.850006  181.770004  180.389999  181.749893
# 2022-01-03 11:30:00-05:00  181.750000  181.770004  181.074997  181.600006
# 2022-01-03 12:30:00-05:00  181.595001  182.279007  181.490005  182.229706
# 2022-01-03 13:30:00-05:00  182.225006  182.880005  181.809998  181.865005
# ...                               ...         ...         ...         ...
# 2023-03-03 11:30:00-05:00  149.574997  150.029999  149.259995  149.914200
# 2023-03-03 12:30:00-05:00  149.914993  150.320007  149.600098  150.101395
# 2023-03-03 13:30:00-05:00  150.104996  150.809998  149.910004  150.759995
# 2023-03-03 14:30:00-05:00  150.759995  150.970001  150.620193  150.919998
# 2023-03-03 15:30:00-05:00  150.910004  151.110001  150.529999  151.100006
#
#                             Adj Close    Volume
# Datetime
# 2022-01-03 09:30:00-05:00  180.839996  25170269
# 2022-01-03 10:30:00-05:00  181.749893  11976542
# 2022-01-03 11:30:00-05:00  181.600006   8143152
# 2022-01-03 12:30:00-05:00  182.229706   8407914
# 2022-01-03 13:30:00-05:00  181.865005  11618629
# ...                               ...       ...
# 2023-03-03 11:30:00-05:00  149.914200   6663071
# 2023-03-03 12:30:00-05:00  150.101395   6588836
# 2023-03-03 13:30:00-05:00  150.759995   5696300
# 2023-03-03 14:30:00-05:00  150.919998   6227515
# 2023-03-03 15:30:00-05:00  151.100006   7447622
#
# [2047 rows x 6 columns]

# %%
https://www.mlfinlab.com/en/latest/
# Out:
#   Cell In[13], line 1
#     https://www.mlfinlab.com/en/latest/
#           ^
# SyntaxError: invalid syntax

# %%
data.Open.plot()
# Out:
# <Axes: xlabel='Datetime'>

# %% [markdown]
# # example FinRL

# %% [markdown]
# import pkg_resources
# import pip
# installedPackages = {pkg.key for pkg in pkg_resources.working_set}
# required = {'yfinance', 'pandas', 'matplotlib', 'stockstats','stable-baselines','gym','tensorflow'}
# missing = required - installedPackages
# if missing:
#     !pip install yfinance
#     !pip install pandas
#     !pip install matplotlib
#     !pip install stockstats
#     !pip install gym
#     !pip install stable-baselines[mpi]
#     !pip install tensorflow==1.15.4

# %%
# !pip uninstall tensorflow

# %%
import yfinance as yf
from stockstats import StockDataFrame as Sdf

import pandas as pd
import matplotlib.pyplot as plt

import gym
from stable_baselines import PPO2, DDPG, A2C, ACKTR, TD3
from stable_baselines import DDPG
from stable_baselines import A2C
from stable_baselines import SAC
from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines.common.policies import MlpPolicy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 8
#       5 import matplotlib.pyplot as plt
#       7 import gym
# ----> 8 from stable_baselines import PPO2, DDPG, A2C, ACKTR, TD3
#       9 from stable_baselines import DDPG
#      10 from stable_baselines import A2C
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines\__init__.py:7
#       5 from stable_baselines.acer import ACER
#       6 from stable_baselines.acktr import ACKTR
# ----> 7 from stable_baselines.deepq import DQN
#       8 from stable_baselines.her import HER
#       9 from stable_baselines.ppo2 import PPO2
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines\deepq\__init__.py:1
# ----> 1 from stable_baselines.deepq.policies import MlpPolicy, CnnPolicy, LnMlpPolicy, LnCnnPolicy
#       2 from stable_baselines.deepq.build_graph import build_act, build_train  # noqa
#       3 from stable_baselines.deepq.dqn import DQN
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines\deepq\policies.py:2
#       1 import tensorflow as tf
# ----> 2 import tensorflow.contrib.layers as tf_layers
#       3 import numpy as np
#       4 from gym.spaces import Discrete
#
# ModuleNotFoundError: No module named 'tensorflow.contrib'
